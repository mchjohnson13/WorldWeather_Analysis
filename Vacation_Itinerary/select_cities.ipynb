# %%
# Dependencies and Setup
import pandas as pd

# %%
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp Current Description    Lat  \
# 0        0        Celestun      MX     77.25     overcast clouds  20.87
# 1        2        Maragogi      BR     71.44     overcast clouds  -9.01
# 2        6  Ribeira Grande      PT     73.02           clear sky  38.52
# 3        9          Beidao      CN     76.62           clear sky  34.57
# 4       10     San Quintin      MX     74.91           clear sky  30.48
#
#       Lng                                         Hotel Name
# 0  -90.40                                       Posada Lilia
# 1  -35.22           Salinas do Maragogi All Inclusive Resort
# 2  -28.70                                Quinta da Meia Eira
# 3  105.89  Shell Tianshui Maiji District Erma Road Walkin...
# 4 -115.95                                     Old Mill Hotel

# %%
vacation_df = vacation_df.loc[(vacation_df["Country"] == "MX")]
vacation_df
# Out:
#      City_ID              City Country  Max Temp Current Description    Lat  \
# 0          0          Celestun      MX     77.25     overcast clouds  20.87
# 4         10       San Quintin      MX     74.91           clear sky  30.48
# 91       300    Guerrero Negro      MX     74.75           clear sky  27.98
# 100      319  Puerto Escondido      MX     79.05          light rain  15.85
# 104      331   Lazaro Cardenas      MX     79.52          light rain  17.96
# 114      357     General Teran      MX     76.15       moderate rain  25.27
# 147      493          Rosarito      MX     78.01           clear sky  32.33
# 150      500            Nautla      MX     77.41           clear sky  20.22
# 159      524          Acapulco      MX     79.56       moderate rain  16.86
# 169      555            Aldama      MX     79.00          light rain  22.92
# 198      655          Tomatlan      MX     78.17          light rain  19.93
#
#         Lng                         Hotel Name
# 0    -90.40                       Posada Lilia
# 4   -115.95                     Old Mill Hotel
# 91  -114.06       Casa Laguna, Bed & Breakfast
# 100  -97.07      Aldea del Bazar Hotel and Spa
# 104 -102.20  Collection O Hotel Quinta Antigua
# 114  -99.68                   OYO Hotel Garate
# 147 -117.03      Hotel Festival Plaza Rosarito
# 150  -96.78                        Casa Blanca
# 159  -99.89          HS Hotsson Smart Acapulco
# 169  -98.07                         CASA CANYE
# 198 -105.25                       Norma franco
